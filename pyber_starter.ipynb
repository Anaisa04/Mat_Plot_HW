# %%
# %matplotlib inline
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# File to Load (Remember to change these)
city_data= "data/city_data.csv"
ride_data= "data/ride_data.csv"

# Read the City and Ride Data
city_df= pd.read_csv(city_data)
city_df.head()
ride_df=pd.read_csv(ride_data)
ride_df.head()
# Out:
#                  city           date   fare       ride_id
# 0  Lake Jonathanshire  1/14/18 10:14  13.83  5.739410e+12
# 1  South Michelleport   3/4/18 18:24  30.24  2.343910e+12
# 2  Port Samanthamouth   2/24/18 4:29  33.44  2.005070e+12
# 3          Rodneyfort  2/10/18 23:22  23.44  5.149250e+12
# 4          South Jack    3/6/18 4:28  34.58  3.908450e+12

# %%
ride_df.head()
# Out:
#                  city           date   fare       ride_id
# 0  Lake Jonathanshire  1/14/18 10:14  13.83  5.739410e+12
# 1  South Michelleport   3/4/18 18:24  30.24  2.343910e+12
# 2  Port Samanthamouth   2/24/18 4:29  33.44  2.005070e+12
# 3          Rodneyfort  2/10/18 23:22  23.44  5.149250e+12
# 4          South Jack    3/6/18 4:28  34.58  3.908450e+12

# %%
city_df.head()
# Out:
#            city  driver_count   type
# 0   Richardfort            38  Urban
# 1  Williamsstad            59  Urban
# 2   Port Angela            67  Urban
# 3    Rodneyfort            34  Urban
# 4   West Robert            39  Urban

# %%
# Combine the data into a single dataset
ridecity_df=pd.merge(ride_df,city_df,how="left",on=["city"])
ridecity_df.head()
# Out:
#                  city           date   fare       ride_id  driver_count   type
# 0  Lake Jonathanshire  1/14/18 10:14  13.83  5.739410e+12             5  Urban
# 1  South Michelleport   3/4/18 18:24  30.24  2.343910e+12            72  Urban
# 2  Port Samanthamouth   2/24/18 4:29  33.44  2.005070e+12            57  Urban
# 3          Rodneyfort  2/10/18 23:22  23.44  5.149250e+12            34  Urban
# 4          South Jack    3/6/18 4:28  34.58  3.908450e+12            46  Urban

# %% [markdown]
# ## Bubble Plot of Ride Sharing Data

# %%
# Obtain the x and y coordinates for each of the three city types
# Build the scatter plots for each city types
# Incorporate the other graph properties
# Create a legend
# Incorporate a text label regarding circle size

# Save Figure
#Same for all 
#each df do a group by city (one count ride ids to get count of # of rides)
#then take avgmean of fare

# %%
#Create Urban DF & get the ride_id count,avg fare, and driver counts  
urban_df = ridecity_df[ridecity_df["type"]=="Urban"]
u_ride = urban_df.groupby(["city"]).count()["ride_id"]
u_fare = urban_df.groupby(["city"]).mean()["fare"]
u_drivercount = urban_df.groupby(["city"]).mean()["driver_count"]
urban_df=urban_df.set_index('city')['type']
urban_df
urban_city=pd.DataFrame({
    "Number of Rides": u_ride,
    "Average Fare": u_fare,
    "Number of Drivers":u_drivercount,
})
urban_city

urban_city.sort_values("Number of Drivers",ascending=False)
# Out:
#                       Number of Rides  Average Fare  Number of Drivers
# city
# West Samuelburgh                   25     21.767600                 73
# South Michelleport                 31     24.451613                 72
# West Anthony                       30     24.736667                 70
# Liumouth                           33     26.150000                 69
# Reynoldsfurt                       19     21.919474                 67
# Port Angela                        19     23.836842                 67
# East Kaylahaven                    29     23.757931                 65
# Royland                            30     20.570667                 64
# Jerryton                           25     25.649200                 64
# Grahamburgh                        25     25.221200                 61
# Williamsstad                       23     24.362174                 59
# Pattyland                          21     23.980476                 59
# Lake Scottton                      24     23.809167                 58
# West Gabriel                       23     20.346087                 57
# Port Samanthamouth                 25     25.642800                 57
# Carriemouth                        27     28.314444                 52
# New Jacobville                     18     26.765556                 50
# Deanville                          19     25.842632                 49
# West Angela                        39     25.990000                 48
# Roberthaven                        24     23.729167                 47
# South Jack                         19     22.965263                 46
# Williamsview                       20     26.599000                 46
# Valentineton                       22     24.636364                 45
# West Josephberg                    26     21.720385                 45
# New Paulton                        19     27.820000                 44
# New Paulville                      22     21.675909                 44
# Christopherfurt                    27     24.501852                 41
# Joneschester                       25     22.289600                 39
# Justinberg                         30     23.694333                 39
# West Robert                        31     25.123871                 39
# ...                               ...           ...                ...
# North Jasmine                      30     25.205333                 33
# New Kimberlyborough                30     22.589000                 33
# West Christopherberg               26     24.421154                 32
# West Heidi                         28     23.133929                 28
# Johnton                            21     26.785714                 27
# Barajasview                        22     25.332273                 26
# West Ericstad                      18     22.347222                 25
# West Patrickchester                16     28.233125                 25
# Martinezhaven                      24     22.651250                 25
# Rogerston                          22     22.097727                 25
# Port Frank                         33     27.201515                 23
# Loganberg                          28     25.292500                 23
# Karenberg                          17     26.340000                 22
# North Markport                     14     27.504286                 22
# Simpsonburgh                       24     23.355833                 21
# North Madeline                     25     22.623600                 19
# Lake Danielberg                    26     24.844231                 19
# North Barbara                      22     23.494091                 18
# Leahton                            21     21.243810                 17
# Amandaburgh                        18     24.641667                 12
# Robertport                         20     23.060500                 12
# South Evanton                      31     26.726129                 11
# Raymondhaven                       25     21.480400                 11
# South Latoya                       19     20.093158                 10
# Port David                         22     25.855000                  7
# North Jason                        35     22.743714                  6
# Karenside                          28     27.453571                  5
# Lake Jonathanshire                 24     23.425833                  5
# South Karenland                    38     26.535526                  4
# Port Johnbury                      22     23.006364                  3
#
# [66 rows x 3 columns]

# %%
#Create Subrban DF & get the ride_id count,avg fare, and driver counts  
suburban_df = ridecity_df[ridecity_df["type"]=="Suburban"]
sub_ride = suburban_df.groupby(["city"]).count()["ride_id"]
sub_fare = suburban_df.groupby(["city"]).mean()["fare"]
sub_drivercount = suburban_df.groupby(["city"]).mean()["driver_count"]

sub_city=pd.DataFrame({
    "Number of Rides": sub_ride,
    "Average Fare": sub_fare,
    "Number of Drivers":sub_drivercount,
})


sub_city

sub_city.sort_values("Number of Drivers",ascending=False)
# Out:
#                     Number of Rides  Average Fare  Number of Drivers
# city
# Josephside                       27     32.858148                 25
# Lewishaven                       12     25.241667                 23
# Colemanland                      22     30.894545                 23
# Davidfurt                        17     31.995882                 23
# Lake Scott                       18     31.886111                 23
# Bethanyland                      18     32.956111                 22
# East Danielview                  17     31.560588                 22
# Lake Omar                        14     28.075000                 22
# South Teresa                     22     31.220455                 21
# New Olivia                       17     34.054118                 20
# East Kentstad                    13     29.823077                 20
# Veronicaberg                     17     32.828235                 20
# New Shannonberg                  17     28.378235                 20
# Rodriguezview                    15     30.745333                 20
# Nicolechester                    19     30.909474                 19
# Myersshire                       16     30.203125                 19
# New Raymond                      22     27.961818                 17
# Victoriaport                     14     27.780000                 16
# Mezachester                      17     30.760000                 14
# West Hannah                      21     29.547619                 12
# North Jeffrey                    13     29.242308                 11
# Barronchester                    16     36.422500                 11
# Sotoville                        11     31.980000                 10
# Brandonfort                      19     35.437368                 10
# North Timothy                    15     31.262000                  7
# Port Shane                       19     31.077895                  7
# East Aaronbury                    9     25.661111                  7
# East Marymouth                   27     30.835185                  5
# Lewisland                        17     34.614118                  4
# Lake Robertside                  25     31.262000                  4
# West Kimmouth                    20     29.871500                  4
# Lake Ann                         12     30.890000                  3
# Grayville                        15     27.763333                  2
# Williamsonville                  14     31.875000                  2
# North Richardhaven               14     24.704286                  1
# South Brenda                     24     33.964583                  1

# %%
#Create Rural DF & get the ride_id count,avg fare, and driver counts  
rural_df = ridecity_df[ridecity_df["type"]=="Rural"]
rural_ride = rural_df.groupby(["city"]).count()["ride_id"]
rural_fare = rural_df.groupby(["city"]).mean()["fare"]
rural_drivercount = rural_df.groupby(["city"]).mean()["driver_count"]
rural_city=pd.DataFrame({
    "Number of Rides": rural_ride,
    "Average Fare": rural_fare,
    "Number of Drivers":rural_drivercount,
})

rural_city

rural_city.sort_values("Number of Drivers",ascending=False)

plt.scatter(sub_city["Number of Rides"],sub_city["Average Fare"],s=sub_city["Number of Drivers"]*10,c="blue",edgecolor="black",label="Suburban")
plt.scatter(urban_city["Number of Rides"],urban_city["Average Fare"],s=urban_city["Number of Drivers"]*10,c="orange",edgecolor="black",label="Urban")
plt.scatter(rural_city["Number of Rides"],rural_city["Average Fare"],s=rural_city["Number of Drivers"]*10,c="green",edgecolor="black",label="Rural")

#add labels, legend 
plt.title("Pyber Ride Sharing Data (2016)")
plt.ylabel("Average Fare($)")
plt.xlabel("Total Number of Rides (Per City)")
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# ## Total Fares by City Type

# %%
#Create Rural DF & get the ride_id count,avg fare, and driver counts  
urban_df = ridecity_df[ridecity_df["type"]=="Urban"]
u_ride = urban_df.groupby(["city"]).count()["ride_id"]
u_fare1 = urban_df.groupby(["city"]).sum()["fare"]
u_drivercount = urban_df.groupby(["city"]).mean()["driver_count"]
urban_df=urban_df.set_index('city')['type']
urban_city1=pd.DataFrame({
    "Number of Rides": u_ride,
    "Fare (sum)": u_fare1,
    "Number of Drivers":u_drivercount,
})


rural_df = ridecity_df[ridecity_df["type"]=="Rural"]
rural_ride = rural_df.groupby(["city"]).count()["ride_id"]
rural_fare1 = rural_df.groupby(["city"]).sum()["fare"]
rural_drivercount = rural_df.groupby(["city"]).mean()["driver_count"]
rural_city1=pd.DataFrame({
    "Number of Rides": rural_ride,
    "Fare (sum)": rural_fare1,
    "Number of Drivers":rural_drivercount,
})

suburban_df = ridecity_df[ridecity_df["type"]=="Suburban"]
sub_ride = suburban_df.groupby(["city"]).count()["ride_id"]
sub_fare1 = suburban_df.groupby(["city"]).sum()["fare"]
sub_drivercount = suburban_df.groupby(["city"]).mean()["driver_count"]
sub_city1=pd.DataFrame({
    "Number of Rides": sub_ride,
    "Fare (sum)": sub_fare1,
    "Number of Drivers":sub_drivercount,
})



RuralSum = rural_city1["Fare (sum)"].sum()
SubSum=sub_city1["Fare (sum)"].sum()
UrbanSum=urban_city1["Fare (sum)"].sum()
l = [UrbanSum,SubSum,RuralSum]
Total = UrbanSum+ RuralSum + SubSum
l1 = ["Urban","Suburban","Rural"]
U = round(UrbanSum/Total * 100,1)
R = round(RuralSum/Total * 100,1)
S = round(SubSum/Total * 100, 1)
explode = [0.1,0,0]
plt.pie(l,labels =l1, startangle = 60,autopct='%1.1f%%',shadow = True, explode = explode)
plt.title("% Total Fares by city type")
plt.show()

# %%
# Calculate Type Percents

# Build Pie Chart

# Save Figure

# %%
# Show Figure
#plt.show()

# %% [markdown]
# ## Total Rides by City Type

# %%
# Calculate Ride Percents

# Build Pie Chart

# Save Figure

# %%
urban_df = ridecity_df[ridecity_df["type"]=="Urban"]
u_ride1 = urban_df.groupby(["city"]).sum()["ride_id"]
u_fare = urban_df.groupby(["city"]).mean()["fare"]
u_drivercount = urban_df.groupby(["city"]).mean()["driver_count"]
urban_df=urban_df.set_index('city')['type']
urban_df
urban_city2=pd.DataFrame({
    "Rides": u_ride1,
    "Average Fare": u_fare,
    "Number of Drivers":u_drivercount,
})


rural_df = ridecity_df[ridecity_df["type"]=="Rural"]
rural_ride1 = rural_df.groupby(["city"]).sum()["ride_id"]
rural_fare = rural_df.groupby(["city"]).mean()["fare"]
rural_drivercount = rural_df.groupby(["city"]).mean()["driver_count"]
rural_city2=pd.DataFrame({
    "Rides": rural_ride1,
    "Average Fare": rural_fare,
    "Number of Drivers":rural_drivercount,
})

suburban_df = ridecity_df[ridecity_df["type"]=="Suburban"]
sub_ride1 = suburban_df.groupby(["city"]).sum()["ride_id"]
sub_fare = suburban_df.groupby(["city"]).mean()["fare"]
sub_drivercount = suburban_df.groupby(["city"]).mean()["driver_count"]

sub_city2=pd.DataFrame({
    "Rides": sub_ride1,
    "Average Fare": sub_fare,
    "Number of Drivers":sub_drivercount,
})


RuralSum1 = rural_city2["Rides"].sum()
SubSum1=sub_city2["Rides"].sum()
UrbanSum1=urban_city2["Rides"].sum()
l2 = [UrbanSum1,SubSum1,RuralSum1]
Total = UrbanSum1+ RuralSum1 + SubSum1
l3 = ["Urban","Suburban","Rural"]
U1 = round(UrbanSum1/Total * 100,1)
R1 = round(RuralSum1/Total * 100,1)
S1 = round(SubSum1/Total * 100, 1)
explode = [0.1,0,0]
plt.pie(l2,labels =l3, startangle = 60,autopct='%1.1f%%',shadow = True, explode = explode)
plt.title(" % Total Rides by City Type")
plt.show()

# %%
# Show Figure
#plt.show()

# %% [markdown]
# ## Total Drivers by City Type

# %%
# Calculate Driver Percents
total_drivers = city_df.copy()
# Build Pie Charts
tdgb = total_drivers.groupby(["type"])["driver_count"].sum()
# Save Figure #reset index converts GB to DF 
tdgb = tdgb.reset_index()
tdgb["driver_count_perc"] = (tdgb["driver_count"] / tdgb["driver_count"].sum() ) * 100

# %%
tdgb
# Out:
#        type  driver_count  driver_count_perc
# 0     Rural            78           2.623613
# 1  Suburban           490          16.481668
# 2     Urban          2405          80.894719

# %%
urban_df = ridecity_df[ridecity_df["type"]=="Urban"]
u_ride = urban_df.groupby(["city"]).count()["ride_id"]
u_fare = urban_df.groupby(["city"]).mean()["fare"]
u_drivercount1 = urban_df.groupby(["city"]).sum()["driver_count"]
urban_df=urban_df.set_index('city')['type']
urban_city3=pd.DataFrame({
    "Rides": u_ride,
    "Average Fare": u_fare,
    "Drivers":u_drivercount1,
})


rural_df = ridecity_df[ridecity_df["type"]=="Rural"]
rural_ride = rural_df.groupby(["city"]).count()["ride_id"]
rural_fare = rural_df.groupby(["city"]).mean()["fare"]
rural_drivercount1 = rural_df.groupby(["city"]).sum()["driver_count"]
rural_city3=pd.DataFrame({
    "Rides": rural_ride,
    "Average Fare": rural_fare,
    "Drivers":rural_drivercount1,
})

suburban_df = ridecity_df[ridecity_df["type"]=="Suburban"]
sub_ride = suburban_df.groupby(["city"]).sum()["ride_id"]
sub_fare = suburban_df.groupby(["city"]).mean()["fare"]
sub_drivercount1 = suburban_df.groupby(["city"]).sum()["driver_count"]

sub_city3=pd.DataFrame({
    "Rides": sub_ride,
    "Average Fare": sub_fare,
    "Drivers":sub_drivercount1,
})


RuralSum2 = rural_city3["Drivers"].sum()
SubSum2=sub_city3["Drivers"].sum()
UrbanSum2=urban_city3["Drivers"].sum()
l3 = [UrbanSum2,SubSum2,RuralSum2]
Total = UrbanSum2+ RuralSum2 + SubSum2
l4 = ["Urban","Suburban","Rural"]
U2 = round(UrbanSum2/Total * 100,1)
R2 = round(RuralSum2/Total * 100,1)
S2 = round(SubSum2/Total * 100, 1)
explode = [0.1,0,0]
plt.pie(l3,labels =l4, startangle = 60,autopct='%1.1f%%',shadow = True, explode = explode)
plt.title(" % Total Drivers by City Type")
plt.show()

# %%
# Show Figure
#plt.show()
